# %%
#1-----------------------------------------------------------------------------------------------------------------
#동적 페이지 크롤링 => 최초 10개 까지만 보여진다. => 이럴 떄 selenium이 필요하다. 
#user-agent로 한국어 페이지로 접근하기 => header 선언 필요
#영화 제목 찍어보기
#10개밖에 못 가져온다. 
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
browser = webdriver.Chrome()
browser.maximize_window()

#페이지 이동
url = "https://play.google.com/store/movies/top"
browser.get(url)

#한번 원하는 방큼 스크롤 내리기  => 자바스크립트 코드가 필요 ㅠ
#browser.execute_script("window.scrollTo(0, 1080)")  #1980X1080 해상도의 경우
#모니터 해상도 높이가 1080인 위치로 스트롤 내리는 것 의미
 
#화면 가장 아래로 스크롤 내리기  => 이것을 반복해야 한다. 높이가 변하지 않을 때까지
#browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")

import time
interval = 2 #2초에 한번씩 스크롤 내리기

# 현재 문서 높이를 가져와서 저장
prev_height = browser.execute_script("return document.body.scrollHeight")

#반복 수행
while True:
    #스크룰을 가장 아래로 내림
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")

    #페이지 2초마다 대기
    time.sleep(interval) 

    #현재 문서 높이를 가져와서 저장
    current_height = browser.execute_script("return document.body.scrollHeight")
    if current_height == prev_height:     #더 이상 로딩되는 게 없을때 반복문 탈출
        break

    prev_height = current_height          #같지 않다 => 새로운 것 로딩 => 다시 한번 더 수행    

print("스크롤 완료")
# Out:
# 스크롤 완료

# %%
#2.----------------------------------------------------------------------------------------------------------------- 
#동적 페이지 크롤링 => 최초 10개 까지만 보여진다. => 이럴 떄 selenium이 필요하다. 
#영화 제목 찍어보기
#10개밖에 못 가져온다. 
#selenimu을 통해서 페이지 소스를 가져오기 때문에, url, headers는 필요가 없다. 

import requests
from bs4 import BeautifulSoup
from selenium import webdriver
browser = webdriver.Chrome()
browser.maximize_window()

#페이지 이동
url = "https://play.google.com/store/movies/top"
browser.get(url)

#한번 원하는 방큼 스크롤 내리기  => 자바스크립트 코드가 필요 ㅠ
#browser.execute_script("window.scrollTo(0, 1080)")  #1980X1080 해상도의 경우
#모니터 해상도 높이가 1080인 위치로 스트롤 내리는 것 의미
 
#화면 가장 아래로 스크롤 내리기  => 이것을 반복해야 한다. 높이가 변하지 않을 때까지
#browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")

import time
interval = 2 #2초에 한번씩 스크롤 내리기

# 현재 문서 높이를 가져와서 저장
prev_height = browser.execute_script("return document.body.scrollHeight")

#반복 수행
while True:
    #스크룰을 가장 아래로 내림
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")

    #페이지 2초마다 대기
    time.sleep(interval) 

    #현재 문서 높이를 가져와서 저장
    current_height = browser.execute_script("return document.body.scrollHeight")
    if current_height == prev_height:     #더 이상 로딩되는 게 없을때 반복문 탈출
        break

    prev_height = current_height          #같지 않다 => 새로운 것 로딩 => 다시 한번 더 수행    

print("스크롤 완료")

#스크래핑 작업 시작
soup = BeautifulSoup(browser.page_source, "lxml")  #★★★★★★★★

#div, class 정보 활용
movies = soup.find_all("div", attrs={"class":"ImZGtf mpg5gc"}) 
print("영화의 총 갯수 ? : ", len(movies))  #=> 10으로 출력된다. => 10개 밖에 출력이 안 되는 이유는 이것이 동적페이지 이기 때문이다. 


for movie in movies:
    title = movie.find("div", attrs={"class":"WsMG1c nnK0zc"}).get_text()
    #글자 정보를 뽑기위해 태그를 보니 위와 같은 태그, 클래스. 거기서 .get_text() 사용해서 정보 추출
    print(title)

#10개밖에 못 가져온다. => 실패. 
#10개까지 밖에 못 가져오는 이유는 태그들이 복잡하게 다른 형식. 상위10와 11개부터 태그들이 다른 형식이다.
# Out:
# 스크롤 완료
# 영화의 총 갯수 ? :  10
# 노바디
# 콰이어트 플레이스 (자막판)
# Cruella
# 캐시트럭
# 고질라 VS. 콩
# 컨저링 3: 악마가 시켰다
# 크루즈 패밀리: 뉴 에이지
# 어벤져스 : 엔드게임 (자막판)
# 라야와 마지막 드래곤
# 테넷

# %%
#3-----------------------------------------------------------------------------------------------------------------
#상위 10개와 하위가 태그 등이 다른 경우
#동적 페이지 크롤링 => 최초 10개 까지만 보여진다. => 이럴 떄 selenium이 필요하다. 
#user-agent로 한국어 페이지로 접근하기 => header 선언 필요
#★★★리스트 방식으로★★★ 영화 제목 찍어보기

import requests
from bs4 import BeautifulSoup
from selenium import webdriver
browser = webdriver.Chrome()
browser.maximize_window()

#페이지 이동
url = "https://play.google.com/store/movies/top"
browser.get(url)

#한번 원하는 방큼 스크롤 내리기  => 자바스크립트 코드가 필요 ㅠ
#browser.execute_script("window.scrollTo(0, 1080)")  #1980X1080 해상도의 경우
 
#한번 화면 가장 아래로 스크롤 내리기  => 이것을 반복해야 한다. 높이가 변하지 않을 때까지
#browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")

import time
interval = 4 #2초에 한번씩 스크롤 내리기

# 현재 문서 높이를 가져와서 저장
prev_height = browser.execute_script("return document.body.scrollHeight")

#반복 수행
while True:
    #스크룰을 가장 아래로 내림
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")

    time.sleep(interval)

    #현재 문서 높이를 가져와서 저장
    current_height = browser.execute_script("return document.body.scrollHeight")
    if current_height == prev_height:
        break

    prev_height = current_height

print("스크롤 완료")

#스크래핑 작업 시작

soup = BeautifulSoup(browser.page_source, "lxml")


#div, class 정보 활용

'''안된 이유와 하는 방법  
#상위 10개의 영화 정보를 보면,"div", attrs={"class":"ImZGtf mpg5gc"}) 이렇게 되어있고. 
(이걸로 구분) 또 아래 어딘가에 "div", attrs={"class":"Vpfmgd}"가 존재한다. 

하지만 11개부터 하위를 보면, c-wiz 태그로 구분하고 그 아래에, "div", attrs={"class":"Vpfmgd}"로 되어있다. 
즉, 태그들이 다르니깐, 그 이하는 크롤링이 안됐으며
이를 해결하려면, class":"ImZGtf mpg5gc 혹은 class":"Vpfmgd 인 조건을 만들어야한다. ==> 리스트 사용
'''

movies = soup.find_all("div", attrs={"class":["ImZGtf mpg5gc", "Vpfmgd"]})   #★★ 리스트 활용 or의 의미 내포
#이렇게 하면 클래스가 list 안에 있는 것과 일치하는 것, 즉 둘 다 가져오는 것 의미                                                                           

for movie in movies:
    title = movie.find("div", attrs={"class":"WsMG1c nnK0zc"}).get_text()
    print(title)
    
#완성. 그러나... 중복되어 나오는 것이 많다. 이유? 말했듯이, 밑에도 Vpfmgd가 있기 때문...하나만 써도 된다.
# Out:
# 스크롤 완료
# 노바디
# 노바디
# 콰이어트 플레이스 (자막판)
# 콰이어트 플레이스 (자막판)
# Cruella
# Cruella
# 캐시트럭
# 캐시트럭
# 고질라 VS. 콩
# 고질라 VS. 콩
# 컨저링 3: 악마가 시켰다
# 컨저링 3: 악마가 시켰다
# 크루즈 패밀리: 뉴 에이지
# 크루즈 패밀리: 뉴 에이지
# 어벤져스 : 엔드게임 (자막판)
# 어벤져스 : 엔드게임 (자막판)
# 라야와 마지막 드래곤
# 라야와 마지막 드래곤
# 테넷
# 테넷
# 너의 이름은. (자막판)
# 소울
# 킬러의 보디가드
# 킬러의 보디가드 무삭제 특별판 (자막판)
# 어벤져스 : 인피니티 워 (자막판)
# 날씨의 아이 (자막)
# 몬스터 헌터 Monster Hunter
# 해리포터와 마법사의 돌
# 조커
# 베놈   Venom
# 스파이더맨: 파 프롬 홈 (자막판)
# 잭 스나이더의 저스티스 리그
# 형님 아내2 (무삭제)
# 겨울왕국 2 (더빙판)
# 분노의 질주: 홉스 & 쇼
# 건마의 신:어린 아내의 알바
# 위대한 쇼맨 (자막판)
# 목소리의 형태 (자막판)
# 레디 플레이어 원
# 스파이더맨 : 뉴 유니버스
# 겨울왕국 2 (자막판)
# 50가지 그림자:해방 (자막판)
# 기생충
# 모탈 컴뱃
# 라라랜드 (자막판)
# 원더우먼 1984
# 존 윅-리로드
# 마크맨
# 미나리
# 일탈여행: 프라이빗 아일랜드
# 분노의 질주 7
# 미스트
# 노매드랜드
# 50가지 그림자: 심연
# 캡틴 아메리카 : 시빌 워 (자막판)
# 라이더스 오브 저스티스
# 씽 (더빙판)
# 모아나 (더빙판)
# 내가 죽기를 바라는 자들
# 일본 막장 불륜 호텔
# 해리포터와 비밀의방
# 더 울프 오브 월스트리트
# 모아나 (자막판)
# 주토피아 (더빙판)
# 스파이더맨: 홈커밍  (자막판)
# 코코 (자막판)
# 아바타
# 쥬라기 월드 : 폴른 킹덤
# 그린랜드
# 마이펫의 이중생활 2
# 해리포터와 아즈카반의 죄수
# 존윅 3: 파라벨룸
# 주토피아 (자막판)
# 너의 이름은. (더빙판)
# 알라딘 (2019) (자막판)
# 엄마의 남자
# 어벤져스 : 엔드게임 (더빙판)
# 해리포터와 불사조 기사단
# 어벤져스 (자막판)
# 더 스파이
# 조제
# 스캔들
# 헝거게임: 더 파이널
# 나쁜 녀석들 : 포에버 Bad Boys for Life
# 톰과 제리
# 어벤져스 : 인피니티 워 (더빙판)
# 토르 : 라그나로크 (자막판)
# 인터스텔라
# 해리포터와 불의잔
# 삼국지: 무신 조자룡
# 포드 V 페라리 (자막판)
# 컨저링
# 해리포터와 혼혈왕자
# 성판17: 남자들의 17가지 성적 판타지
# 해리포터 시리즈 완결 패키지
# 해리포터와 죽음의 성물 파트 2 (자막판)
# 코코 (더빙판)
# 해리포터와 죽음의 성물 파트1 (자막판)
# 아이언맨
# 바람에 젖은 여자
# 쥬라기 월드
# 헝거게임 : 판엠의 불꽃
# 메이즈 러너: 데스 큐어 (자막판)
# 어벤져스 : 에이지 오브 울트론 (자막판)
# 더 언홀리 Unholy, The
# 아이언맨 3
# 겨울왕국 (더빙판)
# 헝거게임: 모킹제이
# 분노의 질주: 더 익스트림
# 드래곤 길들이기 3 (더빙판)
# 그것: 두 번째 이야기
# 리스타트
# 몬스터 호텔 3 (더빙판)
# 고질라: 킹 오브 몬스터 (자막판)
# 쿵푸팬더 3 (더빙판)
# 분노의 질주: 더 오리지널
# 크루즈패밀리 (더빙판)
# 극장판 콩순이: 장난감나라 대모험
# 페이트 스테이 헤븐즈필 제3장 스프링 송
# 새엄마들 2019
# 분노의 질주: 더 맥시멈
# 아쿠아맨
# 어니스트 씨프
# 스타 이즈 본
# 닥터 스트레인지 (자막판)
# 부산행
# 덫: 치명적인 유혹
# 알리타: 배틀 엔젤 (자막판)
# 자산어보
# 슈퍼 소닉
# 마녀를 잡아라
# 비긴 어게인 (자막판)
# 캡틴 아메리카: 윈터 솔져 (자막판)
# 핵소고지 (자막판)
# 날씨의 아이 (더빙)
# 스파이럴
# 1917
# 다크 나이트
# 2067
# 인천상륙작전
# 아이언맨 2
# 인간중독
# 쓰리 빌보드 (자막판)
# 괴물의 아이 (더빙판)
# 컨저링 2 (자막판)
# 위플래쉬
# 시간을 달리는 소녀_자막 (자막판)
# 패스트 & 퓨리어스 - 도쿄 드리프트
# 라푼젤 (자막판)
# 가디언즈 오브 갤럭시
# 데드풀2 (자막판)
# 그린치 (자막판)
# 보헤미안 랩소디 (자막판)
# 에스파트너
# 퍼시픽 림: 업라이징 (자막판)
# 미드웨이
# 워 위드 그랜파
# 더 파더
# The Meg
# 인사이드 아웃 (자막판)
# 뱅퀴시
# 겨울왕국 (자막판)
# 더 이퀄라이저 2
# 이 멋진 세계에 축복을! 붉은 전설
# 분노의 질주: 언리미티드
# 형님 아내2
# 그레이의 50가지 그림자
# 캐리비안의 해적: 세상의 끝에서
# 토르 : 천둥의 신 (자막판)
# 덫 무삭제판
# 아웃포스트
# 언터처블: 1%의 우정
# 리얼 스틸
# 그린파파야향기
# 전망 좋은 집
# 알라딘 (2019) (더빙판)
# 슈퍼배드 3
# 매트릭스
# 블랙 팬서 (자막판)
# 빅쇼트
# 쌍화점
# 퍼스트 어벤져 (자막판)
# 명탐정 피카츄 (더빙판)
# 스파이 지니어스
# 라이언 일병 구하기
# 파탈
# 미션 임파서블: 폴아웃 (자막판)
# 트랜스포머: 패자의 역습
# 트롤 :월드투어
# 노트북
# 명탐정 피카츄 (자막판)
# 캐리비언의 해적: 블랙펄의 저주
# 가디언즈 오브 갤럭시 VOL. 2 (자막판)
# 원스 어폰 어 타임 인 할리우드  Once upon a Time In... Hollywood (자막판)
# 딸의 친구2
# 미녀와 야수 (자막판)
# 반지의 제왕 : 반지 원정대
# 굿 윌 헌팅
# 스폰지밥 (더빙판)
# 쥬만지 : 넥스트 레벨  Jumanji: The Next Level
# 백두산
# 반도
# 다만악에서구하소서
# 내부자들: 디 오리지널
# 컨저링 (자막판)
# 애나벨 집으로 (자막판)
# 착한아내
# 킹스맨: 시크릿 에이전트
# 인셉션
# 트와일라잇 (자막판)

# %%
#4.-----------------------------------------------------------------------------------------------------------------
# 상위 10개와 하위가 태그 등이 다른 경우
#동적 페이지 크롤링 => 최초 10개 까지만 보여진다. => 이럴 떄 selenium이 필요하다. 
#user-agent로 한국어 페이지로 접근하기 => header 선언 필요
#★★★리스트 방식으로★★★ 영화 제목 찍어보기
#중복 문제 해결하기 => 그냥 해도 된다 ^^
#기타 정보 추가해보기

#3. => 할인된 영화만 가져오기
#동적 페이지 크롤링 => 최초 10개 까지만 보여진다. => 이럴 떄 selenium이 필요하다. 
#user-agent로 한국어 페이지로 접근하기 => header 선언 필요
#영화 제목 찍어보기
#10개밖에 못 가져온다. 
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
browser = webdriver.Chrome()
browser.maximize_window()

#페이지 이동
url = "https://play.google.com/store/movies/top"
browser.get(url)

#한번 원하는 방큼 스크롤 내리기  => 자바스크립트 코드가 필요 ㅠ
#browser.execute_script("window.scrollTo(0, 1080)")  #1980X1080 해상도의 경우
 
#한번 화면 가장 아래로 스크롤 내리기  => 이것을 반복해야 한다. 높이가 변하지 않을 때까지
#browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")

import time
interval = 2 #2초에 한번씩 스크롤 내리기

# 현재 문서 높이를 가져와서 저장
prev_height = browser.execute_script("return document.body.scrollHeight")

#반복 수행
while True:
    #스크룰을 가장 아래로 내림
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")

    time.sleep(interval)

    #현재 문서 높이를 가져와서 저장
    current_height = browser.execute_script("return document.body.scrollHeight")
    if current_height == prev_height:
        break

    prev_height = current_height

print("스크롤 완료")

#스크래핑 작업 시작

soup = BeautifulSoup(browser.page_source, "lxml")


#div, class 정보 활용
movies = soup.find_all("div", attrs={"class":"Vpfmgd"})

for movie in movies:
    title = movie.find("div", attrs={"class":"WsMG1c nnK0zc"}).get_text()
    print("인기 영화 모든 목록 : ", title)

    #할인된 영화들만 모아보기
    #할인 전 가격
    original_price = movie.find("span", attrs={"class":"SUZt4c djCuy"})
    if original_price:
        original_price = original_price.get_text()

    else:
        #print(title, " <할인되지 않은 영화 제외> ")
        continue

#할인 된 가격
price = movie.find("span", attrs={"class":"VfPpfd ZdBevf i5DZme"}).get_text()
# Out:
# 스크롤 완료
# 인기 영화 모든 목록 :  노바디
# 인기 영화 모든 목록 :  콰이어트 플레이스 (자막판)
# 인기 영화 모든 목록 :  Cruella
# 인기 영화 모든 목록 :  캐시트럭
# 인기 영화 모든 목록 :  고질라 VS. 콩
# 인기 영화 모든 목록 :  컨저링 3: 악마가 시켰다
# 인기 영화 모든 목록 :  어벤져스 : 엔드게임 (자막판)
# 인기 영화 모든 목록 :  크루즈 패밀리: 뉴 에이지
# 인기 영화 모든 목록 :  테넷
# 인기 영화 모든 목록 :  너의 이름은. (자막판)
# 인기 영화 모든 목록 :  라야와 마지막 드래곤
# 인기 영화 모든 목록 :  킬러의 보디가드
# 인기 영화 모든 목록 :  소울
# 인기 영화 모든 목록 :  킬러의 보디가드 무삭제 특별판 (자막판)
# 인기 영화 모든 목록 :  어벤져스 : 인피니티 워 (자막판)
# 인기 영화 모든 목록 :  해리포터와 마법사의 돌
# 인기 영화 모든 목록 :  날씨의 아이 (자막)
# 인기 영화 모든 목록 :  스파이더맨: 파 프롬 홈 (자막판)
# 인기 영화 모든 목록 :  조커
# 인기 영화 모든 목록 :  몬스터 헌터 Monster Hunter
# 인기 영화 모든 목록 :  형님 아내2 (무삭제)
# 인기 영화 모든 목록 :  목소리의 형태 (자막판)
# 인기 영화 모든 목록 :  베놈   Venom
# 인기 영화 모든 목록 :  잭 스나이더의 저스티스 리그
# 인기 영화 모든 목록 :  50가지 그림자:해방 (자막판)
# 인기 영화 모든 목록 :  위대한 쇼맨 (자막판)
# 인기 영화 모든 목록 :  건마의 신:어린 아내의 알바
# 인기 영화 모든 목록 :  분노의 질주: 홉스 & 쇼
# 인기 영화 모든 목록 :  기생충
# 인기 영화 모든 목록 :  겨울왕국 2 (더빙판)
# 인기 영화 모든 목록 :  라라랜드 (자막판)
# 인기 영화 모든 목록 :  원더우먼 1984
# 인기 영화 모든 목록 :  레디 플레이어 원
# 인기 영화 모든 목록 :  스파이더맨 : 뉴 유니버스
# 인기 영화 모든 목록 :  캡틴 아메리카 : 시빌 워 (자막판)
# 인기 영화 모든 목록 :  겨울왕국 2 (자막판)
# 인기 영화 모든 목록 :  마크맨
# 인기 영화 모든 목록 :  분노의 질주 7
# 인기 영화 모든 목록 :  모탈 컴뱃
# 인기 영화 모든 목록 :  존 윅-리로드
# 인기 영화 모든 목록 :  미나리
# 인기 영화 모든 목록 :  씽 (더빙판)
# 인기 영화 모든 목록 :  일본 막장 불륜 호텔
# 인기 영화 모든 목록 :  미스트
# 인기 영화 모든 목록 :  일탈여행: 프라이빗 아일랜드
# 인기 영화 모든 목록 :  노매드랜드
# 인기 영화 모든 목록 :  그린랜드
# 인기 영화 모든 목록 :  라이더스 오브 저스티스
# 인기 영화 모든 목록 :  너의 이름은. (더빙판)
# 인기 영화 모든 목록 :  쥬라기 월드 : 폴른 킹덤
# 인기 영화 모든 목록 :  50가지 그림자: 심연
# 인기 영화 모든 목록 :  모아나 (더빙판)
# 인기 영화 모든 목록 :  더 울프 오브 월스트리트
# 인기 영화 모든 목록 :  내가 죽기를 바라는 자들
# 인기 영화 모든 목록 :  해리포터와 비밀의방
# 인기 영화 모든 목록 :  모아나 (자막판)
# 인기 영화 모든 목록 :  주토피아 (더빙판)
# 인기 영화 모든 목록 :  스파이더맨: 홈커밍  (자막판)
# 인기 영화 모든 목록 :  코코 (자막판)
# 인기 영화 모든 목록 :  헝거게임: 더 파이널
# 인기 영화 모든 목록 :  아바타
# 인기 영화 모든 목록 :  알라딘 (2019) (자막판)
# 인기 영화 모든 목록 :  성판17: 남자들의 17가지 성적 판타지
# 인기 영화 모든 목록 :  마이펫의 이중생활 2
# 인기 영화 모든 목록 :  나쁜 녀석들 : 포에버 Bad Boys for Life
# 인기 영화 모든 목록 :  존윅 3: 파라벨룸
# 인기 영화 모든 목록 :  해리포터와 아즈카반의 죄수
# 인기 영화 모든 목록 :  코코 (더빙판)
# 인기 영화 모든 목록 :  컨저링
# 인기 영화 모든 목록 :  주토피아 (자막판)
# 인기 영화 모든 목록 :  인터스텔라
# 인기 영화 모든 목록 :  엄마의 남자
# 인기 영화 모든 목록 :  어벤져스 : 엔드게임 (더빙판)
# 인기 영화 모든 목록 :  해리포터와 불의잔
# 인기 영화 모든 목록 :  해리포터와 불사조 기사단
# 인기 영화 모든 목록 :  어벤져스 (자막판)
# 인기 영화 모든 목록 :  더 스파이
# 인기 영화 모든 목록 :  헝거게임: 모킹제이
# 인기 영화 모든 목록 :  메이즈 러너: 데스 큐어 (자막판)
# 인기 영화 모든 목록 :  어벤져스 : 인피니티 워 (더빙판)
# 인기 영화 모든 목록 :  조제
# 인기 영화 모든 목록 :  드래곤 길들이기 3 (더빙판)
# 인기 영화 모든 목록 :  스캔들
# 인기 영화 모든 목록 :  바람에 젖은 여자
# 인기 영화 모든 목록 :  아이언맨
# 인기 영화 모든 목록 :  톰과 제리
# 인기 영화 모든 목록 :  어벤져스 : 에이지 오브 울트론 (자막판)
# 인기 영화 모든 목록 :  분노의 질주: 더 익스트림
# 인기 영화 모든 목록 :  해리포터와 죽음의 성물 파트 2 (자막판)
# 인기 영화 모든 목록 :  토르 : 라그나로크 (자막판)
# 인기 영화 모든 목록 :  페이트 스테이 헤븐즈필 제3장 스프링 송
# 인기 영화 모든 목록 :  삼국지: 무신 조자룡
# 인기 영화 모든 목록 :  해리포터와 혼혈왕자
# 인기 영화 모든 목록 :  닥터 스트레인지 (자막판)
# 인기 영화 모든 목록 :  헝거게임 : 판엠의 불꽃
# 인기 영화 모든 목록 :  해리포터 시리즈 완결 패키지
# 인기 영화 모든 목록 :  포드 V 페라리 (자막판)
# 인기 영화 모든 목록 :  겨울왕국 (더빙판)
# 인기 영화 모든 목록 :  쿵푸팬더 3 (더빙판)
# 인기 영화 모든 목록 :  날씨의 아이 (더빙)
# 인기 영화 모든 목록 :  캡틴 아메리카: 윈터 솔져 (자막판)
# 인기 영화 모든 목록 :  아이언맨 3
# 인기 영화 모든 목록 :  내부자들: 디 오리지널
# 인기 영화 모든 목록 :  아쿠아맨
# 인기 영화 모든 목록 :  해리포터와 죽음의 성물 파트1 (자막판)
# 인기 영화 모든 목록 :  부산행
# 인기 영화 모든 목록 :  크루즈패밀리 (더빙판)
# 인기 영화 모든 목록 :  리스타트
# 인기 영화 모든 목록 :  몬스터 호텔 3 (더빙판)
# 인기 영화 모든 목록 :  비긴 어게인 (자막판)
# 인기 영화 모든 목록 :  쥬라기 월드
# 인기 영화 모든 목록 :  더 언홀리 Unholy, The
# 인기 영화 모든 목록 :  새엄마들 2019
# 인기 영화 모든 목록 :  고질라: 킹 오브 몬스터 (자막판)
# 인기 영화 모든 목록 :  분노의 질주: 더 오리지널
# 인기 영화 모든 목록 :  어니스트 씨프
# 인기 영화 모든 목록 :  그것: 두 번째 이야기
# 인기 영화 모든 목록 :  인천상륙작전
# 인기 영화 모든 목록 :  1917
# 인기 영화 모든 목록 :  분노의 질주: 더 맥시멈
# 인기 영화 모든 목록 :  스타 이즈 본
# 인기 영화 모든 목록 :  다크 나이트
# 인기 영화 모든 목록 :  쓰리 빌보드 (자막판)
# 인기 영화 모든 목록 :  덫: 치명적인 유혹
# 인기 영화 모든 목록 :  알리타: 배틀 엔젤 (자막판)
# 인기 영화 모든 목록 :  자산어보
# 인기 영화 모든 목록 :  명탐정 피카츄 (더빙판)
# 인기 영화 모든 목록 :  그린파파야향기
# 인기 영화 모든 목록 :  2067
# 인기 영화 모든 목록 :  형님 아내2
# 인기 영화 모든 목록 :  슈퍼 소닉
# 인기 영화 모든 목록 :  마녀를 잡아라
# 인기 영화 모든 목록 :  워 위드 그랜파
# 인기 영화 모든 목록 :  극장판 콩순이: 장난감나라 대모험
# 인기 영화 모든 목록 :  핵소고지 (자막판)
# 인기 영화 모든 목록 :  엔조이닷컴
# 인기 영화 모든 목록 :  스파이럴
# 인기 영화 모든 목록 :  그레이의 50가지 그림자
# 인기 영화 모든 목록 :  슈퍼배드 3
# 인기 영화 모든 목록 :  아이언맨 2
# 인기 영화 모든 목록 :  인간중독
# 인기 영화 모든 목록 :  여고괴담 여섯번째 이야기 : 모교
# 인기 영화 모든 목록 :  괴물의 아이 (더빙판)
# 인기 영화 모든 목록 :  컨저링 2 (자막판)
# 인기 영화 모든 목록 :  위플래쉬
# 인기 영화 모든 목록 :  시간을 달리는 소녀_자막 (자막판)
# 인기 영화 모든 목록 :  패스트 & 퓨리어스 - 도쿄 드리프트
# 인기 영화 모든 목록 :  라푼젤 (자막판)
# 인기 영화 모든 목록 :  가디언즈 오브 갤럭시
# 인기 영화 모든 목록 :  퍼시픽 림: 업라이징 (자막판)
# 인기 영화 모든 목록 :  캐리비안의 해적: 세상의 끝에서
# 인기 영화 모든 목록 :  그린치 (자막판)
# 인기 영화 모든 목록 :  보헤미안 랩소디 (자막판)
# 인기 영화 모든 목록 :  에스파트너
# 인기 영화 모든 목록 :  데드풀2 (자막판)
# 인기 영화 모든 목록 :  더 파더
# 인기 영화 모든 목록 :  The World To Come
# 인기 영화 모든 목록 :  The Meg
# 인기 영화 모든 목록 :  인사이드 아웃 (자막판)
# 인기 영화 모든 목록 :  뱅퀴시
# 인기 영화 모든 목록 :  겨울왕국 (자막판)
# 인기 영화 모든 목록 :  분노의 질주: 언리미티드
# 인기 영화 모든 목록 :  더 이퀄라이저 2
# 인기 영화 모든 목록 :  마이펫의 이중생활 (더빙판)
# 인기 영화 모든 목록 :  미드웨이
# 인기 영화 모든 목록 :  괴물의 아이 (자막판)
# 인기 영화 모든 목록 :  미드소마
# 인기 영화 모든 목록 :  토르 : 천둥의 신 (자막판)
# 인기 영화 모든 목록 :  빅쇼트
# 인기 영화 모든 목록 :  덫 무삭제판
# 인기 영화 모든 목록 :  리틀 포레스트
# 인기 영화 모든 목록 :  아웃포스트
# 인기 영화 모든 목록 :  쥬만지 : 넥스트 레벨  Jumanji: The Next Level
# 인기 영화 모든 목록 :  착한아내
# 인기 영화 모든 목록 :  명탐정 피카츄 (자막판)
# 인기 영화 모든 목록 :  언터처블: 1%의 우정
# 인기 영화 모든 목록 :  굿 윌 헌팅
# 인기 영화 모든 목록 :  스캔들3
# 인기 영화 모든 목록 :  전망 좋은 집
# 인기 영화 모든 목록 :  마틸다
# 인기 영화 모든 목록 :  노트북
# 인기 영화 모든 목록 :  인셉션
# 인기 영화 모든 목록 :  알라딘 (2019) (더빙판)
# 인기 영화 모든 목록 :  매트릭스
# 인기 영화 모든 목록 :  리얼 스틸
# 인기 영화 모든 목록 :  블랙 팬서 (자막판)
# 인기 영화 모든 목록 :  이 멋진 세계에 축복을! 붉은 전설
# 인기 영화 모든 목록 :  쌍화점
# 인기 영화 모든 목록 :  퍼스트 어벤져 (자막판)
# 인기 영화 모든 목록 :  스파이 지니어스
# 인기 영화 모든 목록 :  라이언 일병 구하기
# 인기 영화 모든 목록 :  컨저링 (자막판)
# 인기 영화 모든 목록 :  트랜스포머: 패자의 역습
# 인기 영화 모든 목록 :  트롤 :월드투어
# 인기 영화 모든 목록 :  미션 임파서블: 폴아웃 (자막판)
# 인기 영화 모든 목록 :  반도
# 인기 영화 모든 목록 :  캐리비언의 해적: 블랙펄의 저주
# 인기 영화 모든 목록 :  가디언즈 오브 갤럭시 VOL. 2 (자막판)
# 인기 영화 모든 목록 :  원스 어폰 어 타임 인 할리우드  Once upon a Time In... Hollywood (자막판)
# 인기 영화 모든 목록 :  딸의 친구2
# price :  ₩1,000

# %%
#5.-----------------------------------------------------------------------------------------------------------------
# 상위 10개와 하위가 태그 등이 다른 경우
#동적 페이지 크롤링 => 최초 10개 까지만 보여진다. => 이럴 떄 selenium이 필요하다. 
#user-agent로 한국어 페이지로 접근하기 => header 선언 필요
#★★★리스트 방식으로★★★ 영화 제목 찍어보기
#중복 문제 해결하기 => 그냥 해도 된다 ^^
#기타 정보 추가해보기

#3. => 할인된 영화만 가져오기
#동적 페이지 크롤링 => 최초 10개 까지만 보여진다. => 이럴 떄 selenium이 필요하다. 
#user-agent로 한국어 페이지로 접근하기 => header 선언 필요
#영화 제목 찍어보기
#10개밖에 못 가져온다. 
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
browser = webdriver.Chrome()
browser.maximize_window()

#페이지 이동
url = "https://play.google.com/store/movies/top"
browser.get(url)

#한번 원하는 방큼 스크롤 내리기  => 자바스크립트 코드가 필요 ㅠ
#browser.execute_script("window.scrollTo(0, 1080)")  #1980X1080 해상도의 경우
 
#한번 화면 가장 아래로 스크롤 내리기  => 이것을 반복해야 한다. 높이가 변하지 않을 때까지
#browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")

import time
interval = 2 #2초에 한번씩 스크롤 내리기

# 현재 문서 높이를 가져와서 저장
prev_height = browser.execute_script("return document.body.scrollHeight")

#반복 수행
while True:
    #스크룰을 가장 아래로 내림
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")

    time.sleep(interval)

    #현재 문서 높이를 가져와서 저장
    current_height = browser.execute_script("return document.body.scrollHeight")
    if current_height == prev_height:
        break

    prev_height = current_height

print("스크롤 완료")

#스크래핑 작업 시작

soup = BeautifulSoup(browser.page_source, "lxml")


#div, class 정보 활용
movies = soup.find_all("div", attrs={"class":"Vpfmgd"})

for movie in movies:
    title = movie.find("div", attrs={"class":"WsMG1c nnK0zc"}).get_text()
    #print("인기 영화 모든 목록 : ", title)

    #할인된 영화들만 모아보기
    #할인 전 가격
    original_price = movie.find("span", attrs={"class":"SUZt4c djCuy"}) #찍찍이
    if original_price: #만약 찍찍이들이 있으면
        original_price = original_price.get_text()  #변수에 그 텍스트들을 저장하고  

    else:
        #print(title, " <할인되지 않은 영화 제외> ")
        continue
    #할인 된 가격
    price = movie.find("span", attrs={"class":"VfPpfd ZdBevf i5DZme"}).get_text() #찍찍이 없는거


    #링크
    link = movie.find("a", attrs={"class":"JC71ub"})["href"]
    #~~의 속성으로 href정보를 가져온다. 
    #/store~~~로 시작하므로 앞에 play.google.com + 링크가 필요하다. 
    #즉, http://play.google.com + link 형식

    print(f"제목 : {title}")
    print(f"할인 전 금액 : {original_price}")
    print(f"할인 후 금액 : {price}")
    print("링크 : ", "http://play.gogole.com" + link)
    print("--------------------------------------------------------------------------------------------------------------")


browser.quit()
# Out:
# 스크롤 완료
# 제목 : 스파이더맨: 파 프롬 홈 (자막판)
# 할인 전 금액 : ₩1,800
# 할인 후 금액 : ₩900
# 링크 :  http://play.gogole.com/store/movies/details/%EC%8A%A4%ED%8C%8C%EC%9D%B4%EB%8D%94%EB%A7%A8_%ED%8C%8C_%ED%94%84%EB%A1%AC_%ED%99%88_%EC%9E%90%EB%A7%89%ED%8C%90?id=zsehQ83TtjI
# --------------------------------------------------------------------------------------------------------------
# 제목 : 마크맨
# 할인 전 금액 : ₩7,000
# 할인 후 금액 : ₩5,000
# 링크 :  http://play.gogole.com/store/movies/details/%EB%A7%88%ED%81%AC%EB%A7%A8?id=4IfZtOlXxuA.P
# --------------------------------------------------------------------------------------------------------------
# 제목 : 라이더스 오브 저스티스
# 할인 전 금액 : ₩10,000
# 할인 후 금액 : ₩7,000
# 링크 :  http://play.gogole.com/store/movies/details/%EB%9D%BC%EC%9D%B4%EB%8D%94%EC%8A%A4_%EC%98%A4%EB%B8%8C_%EC%A0%80%EC%8A%A4%ED%8B%B0%EC%8A%A4?id=Kq5hvBpcYA8.P
# --------------------------------------------------------------------------------------------------------------
# 제목 : 내가 죽기를 바라는 자들
# 할인 전 금액 : ₩14,900
# 할인 후 금액 : ₩9,900
# 링크 :  http://play.gogole.com/store/movies/details/%EB%82%B4%EA%B0%80_%EC%A3%BD%EA%B8%B0%EB%A5%BC_%EB%B0%94%EB%9D%BC%EB%8A%94_%EC%9E%90%EB%93%A4?id=Urp3ar5o70g.P
# --------------------------------------------------------------------------------------------------------------
# 제목 : 더 스파이
# 할인 전 금액 : ₩10,000
# 할인 후 금액 : ₩7,000
# 링크 :  http://play.gogole.com/store/movies/details/%EB%8D%94_%EC%8A%A4%ED%8C%8C%EC%9D%B4?id=rD0h6sSPMNA.P
# --------------------------------------------------------------------------------------------------------------
# 제목 : 삼국지: 무신 조자룡
# 할인 전 금액 : ₩10,000
# 할인 후 금액 : ₩5,000
# 링크 :  http://play.gogole.com/store/movies/details/%EC%82%BC%EA%B5%AD%EC%A7%80_%EB%AC%B4%EC%8B%A0_%EC%A1%B0%EC%9E%90%EB%A3%A1?id=BliyeZrAeRc.P
# --------------------------------------------------------------------------------------------------------------
# 제목 : 해리포터 시리즈 완결 패키지
# 할인 전 금액 : ₩36,000
# 할인 후 금액 : ₩18,900
# 링크 :  http://play.gogole.com/store/movies/details/%ED%95%B4%EB%A6%AC%ED%8F%AC%ED%84%B0_%EC%8B%9C%EB%A6%AC%EC%A6%88_%EC%99%84%EA%B2%B0_%ED%8C%A8%ED%82%A4%EC%A7%80?id=DsVgRu5dDdY
# --------------------------------------------------------------------------------------------------------------
# 제목 : 어니스트 씨프
# 할인 전 금액 : ₩4,500
# 할인 후 금액 : ₩2,500
# 링크 :  http://play.gogole.com/store/movies/details/%EC%96%B4%EB%8B%88%EC%8A%A4%ED%8A%B8_%EC%94%A8%ED%94%84?id=Yu_uZoDZHHE.P
# --------------------------------------------------------------------------------------------------------------
# 제목 : 2067
# 할인 전 금액 : ₩10,000
# 할인 후 금액 : ₩7,000
# 링크 :  http://play.gogole.com/store/movies/details/2067?id=qu9XTqubBzw.P
# --------------------------------------------------------------------------------------------------------------
# 제목 : 워 위드 그랜파
# 할인 전 금액 : ₩5,000
# 할인 후 금액 : ₩2,500
# 링크 :  http://play.gogole.com/store/movies/details/%EC%9B%8C_%EC%9C%84%EB%93%9C_%EA%B7%B8%EB%9E%9C%ED%8C%8C?id=Yv2LXpPWoXo.P
# --------------------------------------------------------------------------------------------------------------
# 제목 : 극장판 콩순이: 장난감나라 대모험
# 할인 전 금액 : ₩10,000
# 할인 후 금액 : ₩5,000
# 링크 :  http://play.gogole.com/store/movies/details/%EA%B7%B9%EC%9E%A5%ED%8C%90_%EC%BD%A9%EC%88%9C%EC%9D%B4_%EC%9E%A5%EB%82%9C%EA%B0%90%EB%82%98%EB%9D%BC_%EB%8C%80%EB%AA%A8%ED%97%98?id=UGTCJWlsljU.P
# --------------------------------------------------------------------------------------------------------------
# 제목 : 스파이럴
# 할인 전 금액 : ₩11,000
# 할인 후 금액 : ₩7,700
# 링크 :  http://play.gogole.com/store/movies/details/%EC%8A%A4%ED%8C%8C%EC%9D%B4%EB%9F%B4?id=V8rkM4-JvFQ.P
# --------------------------------------------------------------------------------------------------------------
# 제목 : The World To Come
# 할인 전 금액 : ₩10,000
# 할인 후 금액 : ₩4,000
# 링크 :  http://play.gogole.com/store/movies/details/The_World_To_Come?id=EKbDwwR5BJ8.P
# --------------------------------------------------------------------------------------------------------------
