# %%
#User_agent 사용후.... 
#4
#다양한 제품의 이름 정보 얻어오기 + 광고제품 제외하기
#+++ 리뷰 100개 이상 이면서 평점 4.5 이상 되는 것만 조회하기
#애플 제품도 제외
#1번 페이지로만 실습했는데 5개 페이스를 다 조회해서 조건에 맞는 정보를 출력하는 방법

import requests
import re       #정규식 쓰려고
from bs4 import BeautifulSoup

headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.190 Safari/537.36"}

for i in range(1, 6):  #책은 5페이지 이므로
    print("현재 페이지 :", i, "입니다")
    url = "https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=user&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPric e=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page={}&rocketAll=false&searchIndexingToken=1=4&backgroundColor=".format(i)


    res = requests.get(url, headers=headers)
    res.raise_for_status()

    soup = BeautifulSoup(res.text, "lxml")

    #노트북에 대한 정보
    items = soup.find_all("li", attrs={"class":re.compile("search-product")})  #정규식을 쓰는 이유? search-product로 시작하는 것을 의미하기 위해서
        #=> 자동으로 li태그중 class정보가 search-product로 시작하는 모든 element를 가져온다.

    #이름, 가격, 평점, 평점 수 가져오기 + 광고제품 제외
    #  +++
    #리뷰 100개 이상이면서 평점 4.5인 이상 인 것만 조회
    for item in items:
        
        #광고제품제외
        ad_badge = item.find("span", attrs={"class":"ad-badge-text"})
        if ad_badge:
            print("  <광고 상품 제외한다>  ")
            continue                        #만약 광고 제품이면 제외하고 continue를 한다.
    
        #이름에서 애플 제품 제외
        name = item.find("div", attrs={"class":"name"}).get_text()   #div태그의 class정보가 name인 것의 첫번째.의 text(이름만)가 필요하므로.  (get.text())사용
        if "Apple" in name:
            print(" <apple 상품 제외 >")
            continue

        #가격
        price =  item.find("strong", attrs={"class":"price-value"}).get_text()  #strong태그의 class가 price-value인 것.의 text가 필요

    
        #평점
        rate = item.find("em", attrs={"class":"rating"})    #평점이 없는 제품도 있기 때문에!!!
        if rate: #만약 rate가 있다면
            rate = rate.get_text()
        else:
            print(" <평점 없는 상품 제외 > ")
            continue     
        
        
        #평가 수
        rate_cnt = item.find("span", attrs={"class":"rating-total-count"})
        if rate_cnt:
            rate_cnt = rate_cnt.get_text()[1:-1]   #(int)로 출력된다. 괄호를 없애야 한다.
                                                  #예를들어, (245)인 경우, 첫 인덱스부터 마지막 인덱스 전이니깐. 마지막 꺼는 포함 시키지 않으므로
        
        #rate_cnt = rate_cnt.get_text()  
        #rate_cnt = rate_cnt[1:-1]          와  rate_cnt = rate_cnt.get_text()[1:-1] 는 같다.

        else:
            print(" <평가 수 없는 상품 제외 > ")
            continue

        #평점 4.5 이상인 경우,     
        if float(rate) >= 4.5 and int(rate_cnt) >= 100:
            print("품명:", name + "    가격:",price + "    평점:",rate + "    평가 수:",rate_cnt)
# Out:
# 현재 페이지 : 1 입니다
# 품명: 삼성전자 플러스2 퓨어화이트 노트북 NT550XDA-K78AW (i7-1165G7 39.6cm WIN10 Home), 포함, 256GB, 16GB    가격: 1,379,000    평점: 5.0    평가 수: 650
# 품명: 삼성전자 노트북9 METAL NT901X5L 가볍고 슬림한 1.29kg 코어i5 SSD256GB 윈10 탑재, 포함, SSD 256GB, 8GB    가격: 676,000    평점: 4.5    평가 수: 291
#  <apple 상품 제외 >
#  <apple 상품 제외 >
#  <apple 상품 제외 >
# 품명: 삼성전자 플러스 플래티넘 티탄 노트북 NT350XCR-AD5AS (i5-10210U 39.6cm), 포함, 256GB, 16GB    가격: 1,037,000    평점: 5.0    평가 수: 226
# 품명: 삼성전자 플러스 퓨어 화이트 노트북 NT350XCR-AD3AW (i3-10110U), 포함, 256GB, 8GB, WIN10 Home, RAM 8GB + SSD 256GB    가격: 823,000    평점: 5.0    평가 수: 225
# 품명: 삼성전자 퓨어 화이트 노트북 NT350XCR-AD5WA-X16G (i5-10210U 39.6cm), 윈도우 미포함, 256GB, 16GB    가격: 863,000    평점: 5.0    평가 수: 215
# 품명: 삼성전자 Plus 2 퓨어화이트 노트북 NT550XDZ-AD1AW (셀러론 6305 39.6cm), 미포함, 256GB, 8GB    가격: 519,000    평점: 5.0    평가 수: 123
# 품명: 삼성전자 Plus 2 퓨어화이트 노트북 NT550XDZ-AD1AW (셀러론 6305 39.6cm), 포함, 256GB, 8GB    가격: 717,000    평점: 5.0    평가 수: 123
# 품명: LG전자 그램17 스노우 화이트 노트북 17ZD90P-GX50K (i5-1135G7 43.1cm), 미포함, 256GB, 8GB    가격: 1,629,000    평점: 5.0    평가 수: 445
#  <apple 상품 제외 >
# 품명: LG전자 울트라PC 노트북 15U40N-GR56K (라이젠5-4500U 39.6cm WIN10 Home), 윈도우 포함, 256GB, 8GB    가격: 999,000    평점: 5.0    평가 수: 100
# 품명: 삼성전자 플러스 퓨어 화이트 노트북 NT350XCR-AD3AW (i3-10110U), 미포함, 256GB, 16GB, WIN미설치,  RAM 8GB + RAM 8GB + SSD 256GB    가격: 713,000    평점: 5.0    평가 수: 225
# 품명: 한성컴퓨터 노트북 올데이롱 블랙 TFX255S (i5-10210U 39.62cm WIN미포함), 미포함, SSD 500GB, 8GB    가격: 799,000    평점: 5.0    평가 수: 110
#  <apple 상품 제외 >
#  <apple 상품 제외 >
# 품명: 삼성전자 퓨어 화이트 노트북 NT350XCR-AD5WA-X (i5-10210U 39.6cm), 윈도우 포함, 256GB, 16GB    가격: 1,035,000    평점: 5.0    평가 수: 215
#  <apple 상품 제외 >
# 현재 페이지 : 2 입니다
#  <apple 상품 제외 >
# 품명: 기가바이트 AORUS 5 MB i5 C 블랙 게이밍노트북 (i5-10200H 39.6cm GTX 1650Ti ), 윈도우 포함, 256GB, 16GB    가격: 1,099,000    평점: 4.5    평가 수: 139
# 품명: 삼성전자 플러스 퓨어 화이트 노트북 NT350XCR-AD3AW (i3-10110U), 포함, 256GB, 16GB, WIN10 Home, RAM 8GB + RAM 8GB + SSD 256GB    가격: 892,000    평점: 5.0    평가 수: 225
# 품명: LG전자 10세대 코어i7 윈10탑재 17형 LG 그램 2020년형 17Z90N 그레이 정품키스킨 증정, 16GB, SSD 512GB, 포함    가격: 1,679,000    평점: 4.5    평가 수: 125
#  <apple 상품 제외 >
# 품명: 삼성전자 갤럭시북 이온2 미스틱화이트 노트북 NT950XDZ-A38AW (i3-1115G4 39.6cm), 포함, 256GB, 8GB    가격: 1,477,000    평점: 5.0    평가 수: 202
# 품명: 삼성전자 플러스 플래티넘 티탄 노트북 NT350XCR-AD5AS (i5-10210U 39.6cm ), 윈도우 미포함, 256GB, 16GB    가격: 863,000    평점: 5.0    평가 수: 226
# 품명: 삼성전자 Plus 2 퓨어화이트 노트북 NT550XDZ-AD1AW (셀러론 6305 39.6cm), 포함, 256GB, 4GB    가격: 647,900    평점: 5.0    평가 수: 123
#  <apple 상품 제외 >
#  <apple 상품 제외 >
# 현재 페이지 : 3 입니다
#  <apple 상품 제외 >
# 품명: 삼성전자 갤럭시북 이온2 미스틱화이트 노트북 NT950XDZ-A38AW (i3-1115G4 39.6cm), 미포함, 256GB, 16GB    가격: 1,349,000    평점: 5.0    평가 수: 202
#  <apple 상품 제외 >
#  <apple 상품 제외 >
#  <apple 상품 제외 >
# 품명: 삼성전자 갤럭시북 이온 아우라실버 노트북 NT950XCR-G58A (i5-10210U 39.6cm MX250), WIN10 Home, RAM 8GB + RAM 8GB + SSD 256GB    가격: 1,698,000    평점: 5.0    평가 수: 148
# 품명: 삼성전자 갤럭시북 이온 노트북 아우라실버 NT950XCR-A58A (i5-10210U), 미포함, NVMe 256GB, 16GB, WIN미포함, RAM 8GB + RAM 8GB + NVMe 256GB    가격: 1,479,000    평점: 4.5    평가 수: 240
# 품명: 삼성전자 노트북7 Force NT760XBV-G58A (i5-8265U 39.6cm GTX1650), 256GB, 8GB, Linux    가격: 1,239,000    평점: 5.0    평가 수: 264
# 현재 페이지 : 4 입니다
# 품명: 삼성전자 갤럭시북 이온 노트북 아우라실버 NT950XCR-A58A (i5-10210U), 포함, NVMe 256GB, 8GB, Win10Home, RAM 8GB + SSD 256GB    가격: 1,579,000    평점: 4.5    평가 수: 240
#  <apple 상품 제외 >
#  <apple 상품 제외 >
#  <apple 상품 제외 >
# 품명: 삼성전자 갤럭시북 이온 Aura Silver 노트북 NT950XCR-G58A(i5-10210U 39.6cm GeForce MX250), NT950XCR-G58A, WIN미포함, RAM 16GB + SSD 256GB    가격: 1,579,000    평점: 5.0    평가 수: 148
# 품명: 기가바이트 AORUS 5 MB i5 C 블랙 게이밍노트북 (i5-10200H 39.6cm GTX 1650Ti ), 윈도우 포함, 512GB, 16GB    가격: 1,149,000    평점: 4.5    평가 수: 139
# 현재 페이지 : 5 입니다
# 품명: 삼성전자 갤럭시북 이온 아우라실버 노트북 NT950XCR-A58A (i5-10210U), 포함, 256GB, 16GB, WIN10 Home, RAM 8GB + RAM 8GB + SSD 256GB    가격: 1,598,000    평점: 4.5    평가 수: 240
# 품명: 삼성전자 플러스2 퓨어화이트 노트북 NT550XDA-K78AW (i7-1165G7 39.6cm WIN10 Home), 포함, 256GB, 8GB    가격: 1,379,000    평점: 5.0    평가 수: 650
#  <apple 상품 제외 >
#  <apple 상품 제외 >
# 품명: 삼성전자 2020 갤럭시북 플렉스 NT950QCG-X716A (i7-1065G7 39.6cm MX250), 1TB, 16GB, WIN10 Home    가격: 2,548,000    평점: 5.0    평가 수: 241

# %%
#User_agent 사용후.... 
#5 정리.
#다양한 제품의 이름 정보 얻어오기 + 광고제품 제외하기
#+++ 리뷰 100개 이상 이면서 평점 4.5 이상 되는 것만 조회하기
#애플 제품도 제외
#1번 페이지로만 실습했는데 5개 페이스를 다 조회해서 조건에 맞는 정보를 출력하는 방법
#정리 및 링크추가

import requests
import re       #정규식 쓰려고
from bs4 import BeautifulSoup

headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.190 Safari/537.36"}

for i in range(1, 6):  #책은 5페이지 이므로
    #print("현재 페이지 :", i, "입니다")
    url = "https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=user&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPric e=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page={}&rocketAll=false&searchIndexingToken=1=4&backgroundColor=".format(i)


    res = requests.get(url, headers=headers)
    res.raise_for_status()

    soup = BeautifulSoup(res.text, "lxml")

    #노트북에 대한 정보
    items = soup.find_all("li", attrs={"class":re.compile("search-product")})  #정규식을 쓰는 이유? search-product로 시작하는 것을 의미하기 위해서
        #=> 자동으로 li태그중 class정보가 search-product로 시작하는 모든 element를 가져온다.

    #이름, 가격, 평점, 평점 수 가져오기 + 광고제품 제외
    #  +++
    #리뷰 100개 이상이면서 평점 4.5인 이상 인 것만 조회
    for item in items:
        
        #광고제품제외
        ad_badge = item.find("span", attrs={"class":"ad-badge-text"})
        if ad_badge:
            #print("  <광고 상품 제외한다>  ")
            continue                        #만약 광고 제품이면 제외하고 continue를 한다.
    
        #이름에서 애플 제품 제외
        name = item.find("div", attrs={"class":"name"}).get_text()   #div태그의 class정보가 name인 것의 첫번째.의 text(이름만)가 필요하므로.  (get.text())사용
        if "Apple" in name:
            #print(" <apple 상품 제외 >")
            continue

        #가격
        price =  item.find("strong", attrs={"class":"price-value"}).get_text()  #strong태그의 class가 price-value인 것.의 text가 필요

    
        #평점
        rate = item.find("em", attrs={"class":"rating"})    #평점이 없는 제품도 있기 때문에!!!
        if rate: #만약 rate가 있다면
            rate = rate.get_text()
        else:
            #print(" <평점 없는 상품 제외 > ")
            continue     
        
        
        #평가 수
        rate_cnt = item.find("span", attrs={"class":"rating-total-count"})
        if rate_cnt:
            rate_cnt = rate_cnt.get_text()[1:-1]   #(int)로 출력된다. 괄호를 없애야 한다.
                                                  #예를들어, (245)인 경우, 첫 인덱스부터 마지막 인덱스 전이니깐. 마지막 꺼는 포함 시키지 않으므로
        
        #rate_cnt = rate_cnt.get_text()  
        #rate_cnt = rate_cnt[1:-1]          와  rate_cnt = rate_cnt.get_text()[1:-1] 는 같다.

        else:
            #print(" <평가 수 없는 상품 제외 > ")
            continue
        
        #링크가져오기  => a태그의 search-product-link 클래스
        link = item.find("a", attrs={"class":"search-product-link"})["href"]  
        #href 정보를 빼내고 앞에 coupang.com이 붙어야한다!!!

        #평점 4.5 이상인 경우,     
        if float(rate) >= 4.5 and int(rate_cnt) >= 100:
            #print("품명:", name + "    가격:",price + "    평점:",rate + "    평가 수:",rate_cnt)
            print(f"제품명 : {name}")
            print(f"가격 : {price}")
            print(f"제품명 : {rate}점 ({rate_cnt}개)")
            print("바로가기 : {}".format("https://www.coupang.com" + link))
            print("----------------------------------------------------------------------------------------------------------- ") #줄긋기
# Out:
# 제품명 : 삼성전자 플러스2 퓨어화이트 노트북 NT550XDA-K78AW (i7-1165G7 39.6cm WIN10 Home), 포함, 256GB, 16GB
# 가격 : 1,379,000
# 제품명 : 5.0점 (650개)
# 바로가기 : https://www.coupang.com/vp/products/4692708274?itemId=5899936424&vendorItemId=73198049954
# -----------------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 노트북9 METAL NT901X5L 가볍고 슬림한 1.29kg 코어i5 SSD256GB 윈10 탑재, 포함, SSD 256GB, 8GB
# 가격 : 676,000
# 제품명 : 4.5점 (291개)
# 바로가기 : https://www.coupang.com/vp/products/4368907108?itemId=5147093216&vendorItemId=72456426781
# -----------------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 플러스 플래티넘 티탄 노트북 NT350XCR-AD5AS (i5-10210U 39.6cm), 포함, 256GB, 16GB
# 가격 : 1,037,000
# 제품명 : 5.0점 (226개)
# 바로가기 : https://www.coupang.com/vp/products/4698390398?itemId=5914456264&vendorItemId=73212517972
# -----------------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 플러스 퓨어 화이트 노트북 NT350XCR-AD3AW (i3-10110U), 포함, 256GB, 8GB, WIN10 Home, RAM 8GB + SSD 256GB
# 가격 : 823,000
# 제품명 : 5.0점 (225개)
# 바로가기 : https://www.coupang.com/vp/products/4698318558?itemId=5914282411&vendorItemId=73212343669
# -----------------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 퓨어 화이트 노트북 NT350XCR-AD5WA-X16G (i5-10210U 39.6cm), 윈도우 미포함, 256GB, 16GB
# 가격 : 863,000
# 제품명 : 5.0점 (215개)
# 바로가기 : https://www.coupang.com/vp/products/1941837559?itemId=3296640474&vendorItemId=71283580310
# -----------------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 Plus 2 퓨어화이트 노트북 NT550XDZ-AD1AW (셀러론 6305 39.6cm), 미포함, 256GB, 8GB
# 가격 : 519,000
# 제품명 : 5.0점 (123개)
# 바로가기 : https://www.coupang.com/vp/products/4711649102?itemId=5945569899&vendorItemId=73243525833
# -----------------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 Plus 2 퓨어화이트 노트북 NT550XDZ-AD1AW (셀러론 6305 39.6cm), 포함, 256GB, 8GB
# 가격 : 717,000
# 제품명 : 5.0점 (123개)
# 바로가기 : https://www.coupang.com/vp/products/4711649102?itemId=5945570305&vendorItemId=73243526116
# -----------------------------------------------------------------------------------------------------------
# 제품명 : LG전자 그램17 스노우 화이트 노트북 17ZD90P-GX50K (i5-1135G7 43.1cm), 미포함, 256GB, 8GB
# 가격 : 1,629,000
# 제품명 : 5.0점 (445개)
# 바로가기 : https://www.coupang.com/vp/products/4619113946?itemId=5721566078&vendorItemId=73020303819
# -----------------------------------------------------------------------------------------------------------
# 제품명 : LG전자 울트라PC 노트북 15U40N-GR56K (라이젠5-4500U 39.6cm WIN10 Home), 윈도우 포함, 256GB, 8GB
# 가격 : 999,000
# 제품명 : 5.0점 (100개)
# 바로가기 : https://www.coupang.com/vp/products/2001200936?itemId=3405196420&vendorItemId=71391804182
# -----------------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 플러스 퓨어 화이트 노트북 NT350XCR-AD3AW (i3-10110U), 미포함, 256GB, 16GB, WIN미설치,  RAM 8GB + RAM 8GB + SSD 256GB
# 가격 : 713,000
# 제품명 : 5.0점 (225개)
# 바로가기 : https://www.coupang.com/vp/products/4698318558?itemId=5945587356&vendorItemId=73243543274
# -----------------------------------------------------------------------------------------------------------
# 제품명 : 한성컴퓨터 노트북 올데이롱 블랙 TFX255S (i5-10210U 39.62cm WIN미포함), 미포함, SSD 500GB, 8GB
# 가격 : 799,000
# 제품명 : 5.0점 (110개)
# 바로가기 : https://www.coupang.com/vp/products/1104993306?itemId=2066003712&vendorItemId=70065189861
# -----------------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 퓨어 화이트 노트북 NT350XCR-AD5WA-X (i5-10210U 39.6cm), 윈도우 포함, 256GB, 16GB
# 가격 : 1,035,000
# 제품명 : 5.0점 (215개)
# 바로가기 : https://www.coupang.com/vp/products/1941837559?itemId=6272853340&vendorItemId=73568469306
# -----------------------------------------------------------------------------------------------------------
# 제품명 : 기가바이트 AORUS 5 MB i5 C 블랙 게이밍노트북 (i5-10200H 39.6cm GTX 1650Ti ), 윈도우 포함, 256GB, 16GB
# 가격 : 1,099,000
# 제품명 : 4.5점 (139개)
# 바로가기 : https://www.coupang.com/vp/products/4366571083?itemId=5142156379&vendorItemId=72451530012
# -----------------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 플러스 퓨어 화이트 노트북 NT350XCR-AD3AW (i3-10110U), 포함, 256GB, 16GB, WIN10 Home, RAM 8GB + RAM 8GB + SSD 256GB
# 가격 : 892,000
# 제품명 : 5.0점 (225개)
# 바로가기 : https://www.coupang.com/vp/products/4698318558?itemId=5945798259&vendorItemId=73243753249
# -----------------------------------------------------------------------------------------------------------
# 제품명 : LG전자 10세대 코어i7 윈10탑재 17형 LG 그램 2020년형 17Z90N 그레이 정품키스킨 증정, 16GB, SSD 512GB, 포함
# 가격 : 1,679,000
# 제품명 : 4.5점 (125개)
# 바로가기 : https://www.coupang.com/vp/products/2239012307?itemId=3824139013&vendorItemId=71320125186
# -----------------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 갤럭시북 이온2 미스틱화이트 노트북 NT950XDZ-A38AW (i3-1115G4 39.6cm), 포함, 256GB, 8GB
# 가격 : 1,477,000
# 제품명 : 5.0점 (202개)
# 바로가기 : https://www.coupang.com/vp/products/4890938544?itemId=5752707261&vendorItemId=73051322555
# -----------------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 플러스 플래티넘 티탄 노트북 NT350XCR-AD5AS (i5-10210U 39.6cm ), 윈도우 미포함, 256GB, 16GB
# 가격 : 863,000
# 제품명 : 5.0점 (226개)
# 바로가기 : https://www.coupang.com/vp/products/4698390398?itemId=6257662779&vendorItemId=73553358500
# -----------------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 Plus 2 퓨어화이트 노트북 NT550XDZ-AD1AW (셀러론 6305 39.6cm), 포함, 256GB, 4GB
# 가격 : 647,900
# 제품명 : 5.0점 (123개)
# 바로가기 : https://www.coupang.com/vp/products/4711649102?itemId=5945570299&vendorItemId=73243526065
# -----------------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 갤럭시북 이온2 미스틱화이트 노트북 NT950XDZ-A38AW (i3-1115G4 39.6cm), 미포함, 256GB, 16GB
# 가격 : 1,349,000
# 제품명 : 5.0점 (202개)
# 바로가기 : https://www.coupang.com/vp/products/4890938544?itemId=5752708209&vendorItemId=73051323428
# -----------------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 갤럭시북 이온 아우라실버 노트북 NT950XCR-G58A (i5-10210U 39.6cm MX250), WIN10 Home, RAM 8GB + RAM 8GB + SSD 256GB
# 가격 : 1,698,000
# 제품명 : 5.0점 (148개)
# 바로가기 : https://www.coupang.com/vp/products/4672371918?itemId=5843780519&vendorItemId=73142074127
# -----------------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 갤럭시북 이온 노트북 아우라실버 NT950XCR-A58A (i5-10210U), 미포함, NVMe 256GB, 16GB, WIN미포함, RAM 8GB + RAM 8GB + NVMe 256GB
# 가격 : 1,479,000
# 제품명 : 4.5점 (240개)
# 바로가기 : https://www.coupang.com/vp/products/1130284847?itemId=3009160294&vendorItemId=70997369721
# -----------------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 노트북7 Force NT760XBV-G58A (i5-8265U 39.6cm GTX1650), 256GB, 8GB, Linux
# 가격 : 1,239,000
# 제품명 : 5.0점 (264개)
# 바로가기 : https://www.coupang.com/vp/products/242636932?itemId=2098714469&vendorItemId=70097614784
# -----------------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 갤럭시북 이온 노트북 아우라실버 NT950XCR-A58A (i5-10210U), 포함, NVMe 256GB, 8GB, Win10Home, RAM 8GB + SSD 256GB
# 가격 : 1,579,000
# 제품명 : 4.5점 (240개)
# 바로가기 : https://www.coupang.com/vp/products/1130284847?itemId=2098033858&vendorItemId=70096918971
# -----------------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 갤럭시북 이온 Aura Silver 노트북 NT950XCR-G58A(i5-10210U 39.6cm GeForce MX250), NT950XCR-G58A, WIN미포함, RAM 16GB + SSD 256GB
# 가격 : 1,579,000
# 제품명 : 5.0점 (148개)
# 바로가기 : https://www.coupang.com/vp/products/4672371918?itemId=3438553996&vendorItemId=71425040479
# -----------------------------------------------------------------------------------------------------------
# 제품명 : 기가바이트 AORUS 5 MB i5 C 블랙 게이밍노트북 (i5-10200H 39.6cm GTX 1650Ti ), 윈도우 포함, 512GB, 16GB
# 가격 : 1,149,000
# 제품명 : 4.5점 (139개)
# 바로가기 : https://www.coupang.com/vp/products/4366571083?itemId=6464260380&vendorItemId=73758675807
# -----------------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 갤럭시북 이온 아우라실버 노트북 NT950XCR-A58A (i5-10210U), 포함, 256GB, 16GB, WIN10 Home, RAM 8GB + RAM 8GB + SSD 256GB
# 가격 : 1,598,000
# 제품명 : 4.5점 (240개)
# 바로가기 : https://www.coupang.com/vp/products/1130284847?itemId=5843780369&vendorItemId=73142074055
# -----------------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 플러스2 퓨어화이트 노트북 NT550XDA-K78AW (i7-1165G7 39.6cm WIN10 Home), 포함, 256GB, 8GB
# 가격 : 1,379,000
# 제품명 : 5.0점 (650개)
# 바로가기 : https://www.coupang.com/vp/products/4692708274?itemId=5899936427&vendorItemId=73198049960
# -----------------------------------------------------------------------------------------------------------
# 제품명 : 삼성전자 2020 갤럭시북 플렉스 NT950QCG-X716A (i7-1065G7 39.6cm MX250), 1TB, 16GB, WIN10 Home
# 가격 : 2,548,000
# 제품명 : 5.0점 (241개)
# 바로가기 : https://www.coupang.com/vp/products/1665581271?itemId=2097952137&vendorItemId=70096835256
# -----------------------------------------------------------------------------------------------------------
