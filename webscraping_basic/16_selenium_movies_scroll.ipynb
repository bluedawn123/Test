# %%
#1
#동적 페이지 크롤링 => 최초 10개 까지만 보여진다. => 이럴 떄 selenium이 필요하다. 
#user-agent로 한국어 페이지로 접근하기 => header 선언 필요
#영화 제목 찍어보기
#10개밖에 못 가져온다. 
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
browser = webdriver.Chrome()
browser.maximize_window()

#페이지 이동
url = "https://play.google.com/store/movies/top"
browser.get(url)

#한번 원하는 방큼 스크롤 내리기  => 자바스크립트 코드가 필요 ㅠ
#browser.execute_script("window.scrollTo(0, 1080)")  #1980X1080 해상도의 경우
 
#한번 화면 가장 아래로 스크롤 내리기  => 이것을 반복해야 한다. 높이가 변하지 않을 때까지
#browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")

import time
interval = 2 #2초에 한번씩 스크롤 내리기

# 현재 문서 높이를 가져와서 저장
prev_height = browser.execute_script("return document.body.scrollHeight")

#반복 수행
while True:
    #스크룰을 가장 아래로 내림
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")

    time.sleep(interval)

    #현재 문서 높이를 가져와서 저장
    current_height = browser.execute_script("return document.body.scrollHeight")
    if current_height == prev_height:
        break

    prev_height = current_height

print("스크롤 완료")

#스크래핑 작업 시작

soup = BeautifulSoup(browser.page_source, "lxml")


#div, class 정보 활용
movies = soup.find_all("div", attrs={"class":"ImZGtf mpg5gc"}) 
print("영화의 총 갯수 ? : ", len(movies))  #=> 10으로 출력된다. => 10개 밖에 출력이 안 되는 이유는 이것이 동적페이지 이기 때문이다. 


for movie in movies:
    title = movie.find("div", attrs={"class":"WsMG1c nnK0zc"}).get_text()
    print(title)

#10개밖에 못 가져온다. => 실패.
# Out:
# 스크롤 완료
# 영화의 총 갯수 ? :  10
# 원더우먼 1984
# 테넷
# 어벤져스 : 엔드게임 (자막판)
# 해리포터와 마법사의 돌
# 날씨의 아이 (자막)
# 너의 이름은. (자막판)
# 미션 파서블
# 조커
# 겨울왕국 2 (더빙판)
# 스파이더맨: 파 프롬 홈 (자막판)

# %%
#2
#동적 페이지 크롤링 => 최초 10개 까지만 보여진다. => 이럴 떄 selenium이 필요하다. 
#user-agent로 한국어 페이지로 접근하기 => header 선언 필요
#영화 제목 찍어보기
#10개밖에 못 가져온다. 
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
browser = webdriver.Chrome()
browser.maximize_window()

#페이지 이동
url = "https://play.google.com/store/movies/top"
browser.get(url)

#한번 원하는 방큼 스크롤 내리기  => 자바스크립트 코드가 필요 ㅠ
#browser.execute_script("window.scrollTo(0, 1080)")  #1980X1080 해상도의 경우
 
#한번 화면 가장 아래로 스크롤 내리기  => 이것을 반복해야 한다. 높이가 변하지 않을 때까지
#browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")

import time
interval = 2 #2초에 한번씩 스크롤 내리기

# 현재 문서 높이를 가져와서 저장
prev_height = browser.execute_script("return document.body.scrollHeight")

#반복 수행
while True:
    #스크룰을 가장 아래로 내림
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")

    time.sleep(interval)

    #현재 문서 높이를 가져와서 저장
    current_height = browser.execute_script("return document.body.scrollHeight")
    if current_height == prev_height:
        break

    prev_height = current_height

print("스크롤 완료")

#스크래핑 작업 시작

soup = BeautifulSoup(browser.page_source, "lxml")


#div, class 정보 활용
movies = soup.find_all("div", attrs={"class":"Vpfmgd"}) #★★ 리스트 활용
                                                                           #이렇게 하면 클래스가 list 안에 있는 것과 일치하는 것, 즉 둘 다 가져오는 것 의미
                                                                           
print("영화의 총 갯수 ? : ", len(movies))  #=> 10으로 출력된다. => 10개 밖에 출력이 안 되는 이유는 이것이 동적페이지 이기 때문이다. 

for movie in movies:
    title = movie.find("div", attrs={"class":"WsMG1c nnK0zc"}).get_text()
    print(title)
    
#완성.
# Out:
# 스크롤 완료
# 영화의 총 갯수 ? :  200
# 원더우먼 1984
# 테넷
# 어벤져스 : 엔드게임 (자막판)
# 해리포터와 마법사의 돌
# 날씨의 아이 (자막)
# 너의 이름은. (자막판)
# 미션 파서블
# 조커
# 겨울왕국 2 (더빙판)
# 스파이더맨: 파 프롬 홈 (자막판)
# 건마의 신:어린 아내의 알바
# 기생충
# 겨울왕국 2 (자막판)
# 덫: 치명적인 유혹
# 프리키 데스데이
# 스파이더맨 : 뉴 유니버스
# 그린랜드
# 해리포터와 비밀의방
# 해리포터와 아즈카반의 죄수
# 성판17: 남자들의 17가지 성적 판타지
# 목소리의 형태 (자막판)
# 베놈   Venom
# 존윅 3: 파라벨룸
# 어벤져스 : 인피니티 워 (자막판)
# 해리포터와 불의잔
# 레디 플레이어 원
# 라라랜드 (자막판)
# 고질라: 킹 오브 몬스터 (자막판)
# 빅쇼트
# 도굴
# 50가지 그림자:해방 (자막판)
# 쥬라기 월드 : 폴른 킹덤 (자막판)
# 스파이더맨: 홈커밍  (자막판)
# 인간중독
# 위대한 쇼맨 (자막판)
# 존 윅-리로드
# 슈퍼배드 3 (더빙판)
# 조제
# 해리포터와 불사조 기사단
# 날씨의 아이 (더빙)
# 착한아내
# 보헤미안 랩소디 (자막판)
# 아웃포스트
# 반도
# 마이펫의 이중생활 2
# 포드 V 페라리 (자막판)
# 마녀를 잡아라
# 주짓수
# 너의 이름은. (더빙판)
# 트롤 :월드투어
# 뱅가드
# 드래곤 길들이기 3 (더빙판)
# 해리포터와 죽음의 성물 파트1 (자막판)
# 해리포터와 죽음의 성물 파트 2 (자막판)
# 쿵푸팬더 3 (더빙판)
# 주토피아 (더빙판)
# 분노의 질주: 홉스 & 쇼
# 미드웨이
# 굿 윌 헌팅
# 아쿠아맨
# 뮬란
# 그레이의 50가지 그림자
# 아바타
# 부산행
# 스타 이즈 본
# 토르 : 라그나로크 (자막판)
# 어벤져스 : 엔드게임 (더빙판)
# 씽 (더빙판)
# 해리포터와 혼혈왕자
# 인턴
# 아키라
# 해리포터 시리즈 완결 패키지
# ...

# %%
#3. => 할인된 영화만 가져오기
#동적 페이지 크롤링 => 최초 10개 까지만 보여진다. => 이럴 떄 selenium이 필요하다. 
#user-agent로 한국어 페이지로 접근하기 => header 선언 필요
#영화 제목 찍어보기
#10개밖에 못 가져온다. 
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
browser = webdriver.Chrome()
browser.maximize_window()

#페이지 이동
url = "https://play.google.com/store/movies/top"
browser.get(url)

#한번 원하는 방큼 스크롤 내리기  => 자바스크립트 코드가 필요 ㅠ
#browser.execute_script("window.scrollTo(0, 1080)")  #1980X1080 해상도의 경우
 
#한번 화면 가장 아래로 스크롤 내리기  => 이것을 반복해야 한다. 높이가 변하지 않을 때까지
#browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")

import time
interval = 2 #2초에 한번씩 스크롤 내리기

# 현재 문서 높이를 가져와서 저장
prev_height = browser.execute_script("return document.body.scrollHeight")

#반복 수행
while True:
    #스크룰을 가장 아래로 내림
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")

    time.sleep(interval)

    #현재 문서 높이를 가져와서 저장
    current_height = browser.execute_script("return document.body.scrollHeight")
    if current_height == prev_height:
        break

    prev_height = current_height

print("스크롤 완료")

#스크래핑 작업 시작

soup = BeautifulSoup(browser.page_source, "lxml")


#div, class 정보 활용
movies = soup.find_all("div", attrs={"class":"Vpfmgd"}) #★★ 리스트 활용
                                                                           #이렇게 하면 클래스가 list 안에 있는 것과 일치하는 것, 즉 둘 다 가져오는 것 의미
                                                                           
#print("영화의 총 갯수 ? : ", len(movies))  #=> 10으로 출력된다. => 10개 밖에 출력이 안 되는 이유는 이것이 동적페이지 이기 때문이다. 

for movie in movies:
    title = movie.find("div", attrs={"class":"WsMG1c nnK0zc"}).get_text()
    #print("인기 영화 모든 목록 : ", title)

    #할인 전 가격
    original_price = movie.find("span", attrs={"class":"SUZt4c djCuy"})
    if original_price:
        original_price = original_price.get_text()

    else:
        #print(title, " <할인되지 않은 영화 제외> ")
        continue

    #할인 된 가격
    price = movie.find("span", attrs={"class":"VfPpfd ZdBevf i5DZme"}).get_text()
    
    #링크
    link = movie.find("a", attrs={"class":"JC71ub"})["href"]  #~~의 속성으로 href정보를 가져온다. 그리고 play.google.com + 링크가 필요하다. 

    print(f"제목 : {title}")
    print(f"할인 전 금액 : {original_price}")
    print(f"할인 후 금액 : {price}")
    print("링크 : ", "http://play.gogole.com" + link)
    print("--------------------------------------------------------------------------------------------------------------------------------------------")

browser.close()

#개발자 도구롤 보니, SUZt4c djCuy 클래스가 있으면 할인전 정보가 있는 것으로 보인다. 이 클래스로 span태그를 찾아 추려보자.
# Out:
# 스크롤 완료
# 제목 : 도굴
# 할인 전 금액 : ₩7,700
# 할인 후 금액 : ₩5,500
# 링크 :  http://play.gogole.com/store/movies/details/%EB%8F%84%EA%B5%B4?id=HQcgbruj254.P
# --------------------------------------------------------------------------------------------------------------------------------------------
# 제목 : 조제
# 할인 전 금액 : ₩11,000
# 할인 후 금액 : ₩5,000
# 링크 :  http://play.gogole.com/store/movies/details/%EC%A1%B0%EC%A0%9C?id=FiwG10w0r7o.P
# --------------------------------------------------------------------------------------------------------------------------------------------
# 제목 : 주짓수
# 할인 전 금액 : ₩10,000
# 할인 후 금액 : ₩5,000
# 링크 :  http://play.gogole.com/store/movies/details/%EC%A3%BC%EC%A7%93%EC%88%98?id=NDGwdH9cCCk.P
# --------------------------------------------------------------------------------------------------------------------------------------------
# 제목 : 뱅가드
# 할인 전 금액 : ₩10,000
# 할인 후 금액 : ₩4,000
# ...
